# %%
a = 1
print(a)
type(print)
# Out:
# 1
# builtin_function_or_method

# %%
#оголошуємо змінну print як int
print = 2
type(print)
# Out:
# int

# %%
#видаляємо змінну print і система розпізнає слово print як команду
del(print)
type(print)
# Out:
# builtin_function_or_method
