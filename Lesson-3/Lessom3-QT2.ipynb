# %%
#1 3 символ
text = 'Quick task'
text[2]
# Out:
# 'i'

# %%
#2 передостанній символ
text[-2]
# Out:
# 's'

# %%
#3 перші 5 символів
text[:5]
# Out:
# 'Quick'

# %%
#4 всі символи крім останніх двох
text[:-2]
# Out:
# 'Quick ta'

# %%
#5 всі парні символи
text[0::2]
# Out:
# 'Qikts'

# %%
#6 всі непарні символи
text[1::2]
# Out:
# 'uc ak'

# %%
#7 стрічка в зворотному порядку
text[-1::-1]
# Out:
# 'ksat kciuQ'

# %%
#8 стрічка в зворотному порядку через один
text[-1::-2]
# Out:
# 'ka cu'

# %%
#9 довжина стрічки
len(text)
# Out:
# 10
