# %%
#1
text = 'Quick task'
text[2]
# Out:
# 'i'

# %%
text[-2]
# Out:
# 's'

# %%
text[:5]
# Out:
# 'Quick'

# %%
text[:-2]
# Out:
# 'Quick ta'

# %%
text[0::2]
# Out:
# 'Qikts'

# %%
text[1::2]
# Out:
# 'uc ak'

# %%
text[-1::-1]
# Out:
# 'ksat kciuQ'

# %%
text[-1::-2]
# Out:
# 'ka cu'

# %%
len(text)
# Out:
# 10
